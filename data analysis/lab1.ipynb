# %%
#given functions wikth n =15
from math import sqrt, log
def naivelog(x):
  n=15           #step size =15
  y = x
  for i in range(n):  #this for loop calculate 15 times of the square root of y, where the initial y = x, same as sqrt(...sqrt(sqrt(x))...)
    y = sqrt(y)
  l = y-1
  for i in range(n):  #this for loop calculate 15 times of the double of given (y-1), same as 2^15*(y-1)
    l = l*2
  return l
x1=naivelog(1)
x1_=log(1)
print("the error between", x1, x1_,"is",abs(x1-x1_))
x2=naivelog(2)
x2_=log(2)
print("the error between", x2, x2_,"is",abs(x2-x2_))
x3=naivelog(3)
x3_=log(3)
print("the error between", x3, x3_,"is",abs(x3-x3_))
x4=naivelog(4)
x4_=log(4)
print("the error between", x4, x4_,"is",abs(x4-x4_))
x5=naivelog(5)
x5_=log(5)
print("the error between", x5, x5_,"is",abs(x5-x5_))
x6=naivelog(6)
x6_=log(6)
print("the error between", x6, x6_,"is",abs(x6-x6_))
x7=naivelog(7)
x7_=log(7)
print("the error between", x7, x7_,"is",abs(x7-x7_))
x8=naivelog(8)
x8_=log(8)
print("the error between", x8, x8_,"is",abs(x8-x8_))
x9=naivelog(9)
x9_=log(9)
print("the error between", x9, x9_,"is",abs(x9-x9_))
x10=naivelog(10)
x10_=log(10)
print("the error between", x10, x10_,"is",abs(x10-x10_))
x11=naivelog(11)
x11_=log(11)
print("the error between", x11, x11_,"is",abs(x11-x11_))
x12=naivelog(12)
x12_=log(12)
print("the error between", x12, x12_,"is",abs(x12-x12_))
x13=naivelog(13)
x13_=log(13)
print("the error between", x13, x13_,"is",abs(x13-x13_))
x14=naivelog(14)
x14_=log(14)
print("the error between", x14, x14_,"is",abs(x14-x14_))
def mylog(x):
  n=15
  z = x-1
  for i in range(n): #this for loop calculate the x/(1+(1+x)^(1/2)) for the given (x-1) for 15 times
    z = z/(1+sqrt(1+z))
  l = z
  for i in range(n):  #this for loop calcualte the output from the last loop and times 2 for 15 times, same as 2^15*z
    l = l*2
  return l
y1=mylog(1)
y1_=log(1)
print("the error between", y1, y1_,"is",abs(y1-y1_))
y2=mylog(2)
y2_=log(2)
print("the error between", y2, y2_,"is",abs(y2-y2_))
y3=mylog(3)
y3_=log(3)
print("the error between", y3, y3_,"is",abs(y3-y3_))
y4=mylog(4)
y4_=log(4)
print("the error between", y4, y4_,"is",abs(y4-y4_))
y5=mylog(5)
y5_=log(5)
print("the error between", y5, y5_,"is",abs(y5-y5_))
y6=mylog(6)
y6_=log(6)
print("the error between", y6, y6_,"is",abs(y6-y6_))
y7=mylog(7)
y7_=log(7)
print("the error between", y7, y7_,"is",abs(y7-y7_))
y8=mylog(8)
y8_=log(8)
print("the error between", y8, y8_,"is",abs(y8-y8_))
y9=mylog(9)
y9_=log(9)
print("the error between", y9, y9_,"is",abs(y9-y9_))
y10=mylog(10)
y10_=log(10)
print("the error between", y10, y10_,"is",abs(y10-y10_))
y11=mylog(11)
y11_=log(11)
print("the error between", y11, y11_,"is",abs(y11-y11_))
y12=mylog(12)
y12_=log(12)
print("the error between", y12, y12_,"is",abs(y12-y12_))
y13=mylog(13)
y13_=log(13)
print("the error between", y13, y13_,"is",abs(y13-y13_))
y14=mylog(14)
y14_=log(14)
print("the error between", y14, y14_,"is",abs(y14-y14_))

#Q1: the work of naivelog is to calculate the estimate result of a log function,through first take n times of the square root to the given input, and multiplyltipy by 2^15.
#  in this case we could estimate theresult of log x, and n here represented the step size, to make a terminal state for the for loop. When x between (0,1) the result will be negative
#  and the mylog function use a more precise way of estimate log x, where the estimate function became x/(1+(1+x)^(1/2)), we loop n times and then multiply by 2^n to get back the precision.
#  in mylog the n parameter also helps form a terminate state for the for loop, aslo provide a relatively accurate enough times of extimate.The larger the  n is, the less error.
# Out:
# the error between 0.0 0.0 is 0.0
# the error between 0.6931545117404312 0.6931471805599453 is 7.33118048590331e-06
# the error between 1.0986307054554345 1.0986122886681098 is 1.8416787324726513e-05
# the error between 1.38632368605613 1.3862943611198906 is 2.9324936239527588e-05
# the error between 1.6094774377779686 1.6094379124341003 is 3.9525343868307417e-05
# the error between 1.7918084569682833 1.791759469228055 is 4.898774022832342e-05
# the error between 1.9459679286155733 1.9459101490553132 is 5.777956026009612e-05
# the error between 2.079507523259963 2.0794415416798357 is 6.598158012716127e-05
# the error between 2.1972982453007717 2.1972245773362196 is 7.366796455210434e-05
# the error between 2.3026659954339266 2.302585092994046 is 8.090243988068124e-05
# the error between 2.3979830114767537 2.3978952727983707 is 8.773867838307581e-05
# the error between 2.485000871543889 2.4849066497880004 is 9.42217558885794e-05
# ...

# %% [markdown]
# Q1:the work of naivelog is to calculate the estimate result of a log function,through first take n times of the square root to the given input, and multiplyltipy by 2^15.
#  in this case we could estimate theresult of log x, and n here represented the step size, to make a terminal state for the for loop. When x between (0,1) the result will be negative
# and the mylog function use a more precise way of estimate log x, where the estimate function became x/(1+(1+x)^(1/2)), we loop n times and then multiply by 2^n to get back the precision.
#  in mylog the n parameter also helps form a terminate state for the for loop, aslo provide a relatively accurate enough times of extimate.The larger the  n is, the less error.

# %% [markdown]
# Q2:the difference performace of naivelog and mylog is caused my the difference in the estimatrion function: the naivelog simply use the suqre root of the original input so as estimate the log result. However the mylog function use x/(1+(1+x)^(1/2)) to estimate the log result,in this case we could get a more preceised estimation of x.

# %%
#given functions wikth n =20
from math import sqrt
def naivelog(x):
  n=20          #step size =20
  y = x
  for i in range(n):  #this for loop calculate 20 times of the square root of y, where the initial y = x, same as sqrt(...sqrt(sqrt(x))...)
    y = sqrt(y)
  l = y-1
  for i in range(n):  #this for loop calculate 20 times of the double of given (y-1), same as 2^20*(y-1)
    l = l*2
  return l
x1=naivelog(1)
x1_=log(1)
print("the error between", x1, x1_,"is",abs(x1-x1_))
x2=naivelog(2)
x2_=log(2)
print("the error between", x2, x2_,"is",abs(x2-x2_))
x3=naivelog(3)
x3_=log(3)
print("the error between", x3, x3_,"is",abs(x3-x3_))
x4=naivelog(4)
x4_=log(4)
print("the error between", x4, x4_,"is",abs(x4-x4_))
x5=naivelog(5)
x5_=log(5)
print("the error between", x5, x5_,"is",abs(x5-x5_))
x6=naivelog(6)
x6_=log(6)
print("the error between", x6, x6_,"is",abs(x6-x6_))
x7=naivelog(7)
x7_=log(7)
print("the error between", x7, x7_,"is",abs(x7-x7_))
x8=naivelog(8)
x8_=log(8)
print("the error between", x8, x8_,"is",abs(x8-x8_))
x9=naivelog(9)
x9_=log(9)
print("the error between", x9, x9_,"is",abs(x9-x9_))
x10=naivelog(10)
x10_=log(10)
print("the error between", x10, x10_,"is",abs(x10-x10_))
x11=naivelog(11)
x11_=log(11)
print("the error between", x11, x11_,"is",abs(x11-x11_))
x12=naivelog(12)
x12_=log(12)
print("the error between", x12, x12_,"is",abs(x12-x12_))
x13=naivelog(13)
x13_=log(13)
print("the error between", x13, x13_,"is",abs(x13-x13_))
x14=naivelog(14)
x14_=log(14)
print("the error between", x14, x14_,"is",abs(x14-x14_))
def mylog(x):
  n=20
  z = x-1
  for i in range(n): #this for loop calculate the x/(1+(1+x)^(1/2)) for the given (x-1) for 20 times
    z = z/(1+sqrt(1+z))
  l = z
  for i in range(n):  #this for loop calcualte the output from the last loop and times 2 for 20 times, same as 2^20*z
    l = l*2
  return l
y1=mylog(1)
y1_=log(1)
print("the error between", y1, y1_,"is",abs(y1-y1_))
y2=mylog(2)
y2_=log(2)
print("the error between", y2, y2_,"is",abs(y2-y2_))
y3=mylog(3)
y3_=log(3)
print("the error between", y3, y3_,"is",abs(y3-y3_))
y4=mylog(4)
y4_=log(4)
print("the error between", y4, y4_,"is",abs(y4-y4_))
y5=mylog(5)
y5_=log(5)
print("the error between", y5, y5_,"is",abs(y5-y5_))
y6=mylog(6)
y6_=log(6)
print("the error between", y6, y6_,"is",abs(y6-y6_))
y7=mylog(7)
y7_=log(7)
print("the error between", y7, y7_,"is",abs(y7-y7_))
y8=mylog(8)
y8_=log(8)
print("the error between", y8, y8_,"is",abs(y8-y8_))
y9=mylog(9)
y9_=log(9)
print("the error between", y9, y9_,"is",abs(y9-y9_))
y10=mylog(10)
y10_=log(10)
print("the error between", y10, y10_,"is",abs(y10-y10_))
y11=mylog(11)
y11_=log(11)
print("the error between", y11, y11_,"is",abs(y11-y11_))
y12=mylog(12)
y12_=log(12)
print("the error between", y12, y12_,"is",abs(y12-y12_))
y13=mylog(13)
y13_=log(13)
print("the error between", y13, y13_,"is",abs(y13-y13_))
y14=mylog(14)
y14_=log(14)
print("the error between", y14, y14_,"is",abs(y14-y14_))
# Out:
# the error between 0.0 0.0 is 0.0
# the error between 0.6931474097073078 0.6931471805599453 is 2.29147362529325e-07
# the error between 1.0986128642689437 1.0986122886681098 is 5.756008338853036e-07
# the error between 1.3862952776253223 1.3862943611198906 is 9.165054317694654e-07
# the error between 1.6094391476362944 1.6094379124341003 is 1.2352021940831293e-06
# the error between 1.791761000175029 1.791759469228055 is 1.5309469740820703e-06
# the error between 1.9459119546227157 1.9459101490553132 is 1.8055674024797241e-06
# the error between 2.079443603521213 2.0794415416798357 is 2.0618413771877897e-06
# the error between 2.197226879419759 2.1972245773362196 is 2.3020835393516847e-06
# the error between 2.302587621146813 2.302585092994046 is 2.5281527671339177e-06
# the error between 2.3978980146348476 2.3978952727983707 is 2.741836476971571e-06
# the error between 2.484909594291821 2.4849066497880004 is 2.9445038207676077e-06
# ...

# %%
#given functions wikth n =25
from math import sqrt
def naivelog(x):
  n=25         #step size =25
  y = x
  for i in range(n):  #this for loop calculate 25 times of the square root of y, where the initial y = x, same as sqrt(...sqrt(sqrt(x))...)
    y = sqrt(y)
  l = y-1
  for i in range(n):  #this for loop calculate 25 times of the double of given (y-1), same as 2^25*(y-1)
    l = l*2
  return l
x1=naivelog(1)
x1_=log(1)
print("the error between", x1, x1_,"is",abs(x1-x1_))
x2=naivelog(2)
x2_=log(2)
print("the error between", x2, x2_,"is",abs(x2-x2_))
x3=naivelog(3)
x3_=log(3)
print("the error between", x3, x3_,"is",abs(x3-x3_))
x4=naivelog(4)
x4_=log(4)
print("the error between", x4, x4_,"is",abs(x4-x4_))
x5=naivelog(5)
x5_=log(5)
print("the error between", x5, x5_,"is",abs(x5-x5_))
x6=naivelog(6)
x6_=log(6)
print("the error between", x6, x6_,"is",abs(x6-x6_))
x7=naivelog(7)
x7_=log(7)
print("the error between", x7, x7_,"is",abs(x7-x7_))
x8=naivelog(8)
x8_=log(8)
print("the error between", x8, x8_,"is",abs(x8-x8_))
x9=naivelog(9)
x9_=log(9)
print("the error between", x9, x9_,"is",abs(x9-x9_))
x10=naivelog(10)
x10_=log(10)
print("the error between", x10, x10_,"is",abs(x10-x10_))
x11=naivelog(11)
x11_=log(11)
print("the error between", x11, x11_,"is",abs(x11-x11_))
x12=naivelog(12)
x12_=log(12)
print("the error between", x12, x12_,"is",abs(x12-x12_))
x13=naivelog(13)
x13_=log(13)
print("the error between", x13, x13_,"is",abs(x13-x13_))
x14=naivelog(14)
x14_=log(14)
print("the error between", x14, x14_,"is",abs(x14-x14_))
def mylog(x):
  n=25
  z = x-1
  for i in range(n): #this for loop calculate the x/(1+(1+x)^(1/2)) for the given (x-1) for 25 times
    z = z/(1+sqrt(1+z))
  l = z
  for i in range(n):  #this for loop calcualte the output from the last loop and times 2 for 25 times, same as 2^25*z
    l = l*2
  return l
y1=mylog(1)
y1_=log(1)
print("the error between", y1, y1_,"is",abs(y1-y1_))
y2=mylog(2)
y2_=log(2)
print("the error between", y2, y2_,"is",abs(y2-y2_))
y3=mylog(3)
y3_=log(3)
print("the error between", y3, y3_,"is",abs(y3-y3_))
y4=mylog(4)
y4_=log(4)
print("the error between", y4, y4_,"is",abs(y4-y4_))
y5=mylog(5)
y5_=log(5)
print("the error between", y5, y5_,"is",abs(y5-y5_))
y6=mylog(6)
y6_=log(6)
print("the error between", y6, y6_,"is",abs(y6-y6_))
y7=mylog(7)
y7_=log(7)
print("the error between", y7, y7_,"is",abs(y7-y7_))
y8=mylog(8)
y8_=log(8)
print("the error between", y8, y8_,"is",abs(y8-y8_))
y9=mylog(9)
y9_=log(9)
print("the error between", y9, y9_,"is",abs(y9-y9_))
y10=mylog(10)
y10_=log(10)
print("the error between", y10, y10_,"is",abs(y10-y10_))
y11=mylog(11)
y11_=log(11)
print("the error between", y11, y11_,"is",abs(y11-y11_))
y12=mylog(12)
y12_=log(12)
print("the error between", y12, y12_,"is",abs(y12-y12_))
y13=mylog(13)
y13_=log(13)
print("the error between", y13, y13_,"is",abs(y13-y13_))
y14=mylog(14)
y14_=log(14)
print("the error between", y14, y14_,"is",abs(y14-y14_))
# Out:
# the error between 0.0 0.0 is 0.0
# the error between 0.6931471899151802 0.6931471805599453 is 9.355234920072064e-09
# the error between 1.0986123085021973 1.0986122886681098 is 1.9834087483516782e-08
# the error between 1.3862943947315216 1.3862943611198906 is 3.3611631033991785e-08
# the error between 1.6094379499554634 1.6094379124341003 is 3.7521363127623886e-08
# the error between 1.7917595207691193 1.791759469228055 is 5.1541064305382633e-08
# the error between 1.9459102004766464 1.9459101490553132 is 5.142133319147035e-08
# the error between 2.0794416069984436 2.0794415416798357 is 6.531860785585764e-08
# the error between 2.197224646806717 2.1972245773362196 is 6.947049735472888e-08
# the error between 2.302585169672966 2.302585092994046 is 7.667892010232435e-08
# the error between 2.397895358502865 2.3978952727983707 is 8.570449416822612e-08
# the error between 2.484906740486622 2.4849066497880004 is 9.069862150212771e-08
# ...

# %%
#given functions wikth n =30
from math import sqrt
def naivelog(x):
  n=30         #step size =30
  y = x
  for i in range(n):  #this for loop calculate 30 times of the square root of y, where the initial y = x, same as sqrt(...sqrt(sqrt(x))...)
    y = sqrt(y)
  l = y-1
  for i in range(n):  #this for loop calculate 30 times of the double of given (y-1), same as 2^30*(y-1)
    l = l*2
  return l
x1=naivelog(1)
x1_=log(1)
print("the error between", x1, x1_,"is",abs(x1-x1_))
x2=naivelog(2)
x2_=log(2)
print("the error between", x2, x2_,"is",abs(x2-x2_))
x3=naivelog(3)
x3_=log(3)
print("the error between", x3, x3_,"is",abs(x3-x3_))
x4=naivelog(4)
x4_=log(4)
print("the error between", x4, x4_,"is",abs(x4-x4_))
x5=naivelog(5)
x5_=log(5)
print("the error between", x5, x5_,"is",abs(x5-x5_))
x6=naivelog(6)
x6_=log(6)
print("the error between", x6, x6_,"is",abs(x6-x6_))
x7=naivelog(7)
x7_=log(7)
print("the error between", x7, x7_,"is",abs(x7-x7_))
x8=naivelog(8)
x8_=log(8)
print("the error between", x8, x8_,"is",abs(x8-x8_))
x9=naivelog(9)
x9_=log(9)
print("the error between", x9, x9_,"is",abs(x9-x9_))
x10=naivelog(10)
x10_=log(10)
print("the error between", x10, x10_,"is",abs(x10-x10_))
x11=naivelog(11)
x11_=log(11)
print("the error between", x11, x11_,"is",abs(x11-x11_))
x12=naivelog(12)
x12_=log(12)
print("the error between", x12, x12_,"is",abs(x12-x12_))
x13=naivelog(13)
x13_=log(13)
print("the error between", x13, x13_,"is",abs(x13-x13_))
x14=naivelog(14)
x14_=log(14)
print("the error between", x14, x14_,"is",abs(x14-x14_))
def mylog(x):
  n=30
  z = x-1
  for i in range(n): #this for loop calculate the x/(1+(1+x)^(1/2)) for the given (x-1) for 30 times
    z = z/(1+sqrt(1+z))
  l = z
  for i in range(n):  #this for loop calcualte the output from the last loop and times 2 for 30 times, same as 2^30*z
    l = l*2
  return l
y1=mylog(1)
y1_=log(1)
print("the error between", y1, y1_,"is",abs(y1-y1_))
y2=mylog(2)
y2_=log(2)
print("the error between", y2, y2_,"is",abs(y2-y2_))
y3=mylog(3)
y3_=log(3)
print("the error between", y3, y3_,"is",abs(y3-y3_))
y4=mylog(4)
y4_=log(4)
print("the error between", y4, y4_,"is",abs(y4-y4_))
y5=mylog(5)
y5_=log(5)
print("the error between", y5, y5_,"is",abs(y5-y5_))
y6=mylog(6)
y6_=log(6)
print("the error between", y6, y6_,"is",abs(y6-y6_))
y7=mylog(7)
y7_=log(7)
print("the error between", y7, y7_,"is",abs(y7-y7_))
y8=mylog(8)
y8_=log(8)
print("the error between", y8, y8_,"is",abs(y8-y8_))
y9=mylog(9)
y9_=log(9)
print("the error between", y9, y9_,"is",abs(y9-y9_))
y10=mylog(10)
y10_=log(10)
print("the error between", y10, y10_,"is",abs(y10-y10_))
y11=mylog(11)
y11_=log(11)
print("the error between", y11, y11_,"is",abs(y11-y11_))
y12=mylog(12)
y12_=log(12)
print("the error between", y12, y12_,"is",abs(y12-y12_))
y13=mylog(13)
y13_=log(13)
print("the error between", y13, y13_,"is",abs(y13-y13_))
y14=mylog(14)
y14_=log(14)
print("the error between", y14, y14_,"is",abs(y14-y14_))
# Out:
# the error between 0.0 0.0 is 0.0
# the error between 0.6931471824645996 0.6931471805599453 is 1.904654323148236e-09
# the error between 1.0986120700836182 1.0986122886681098 is 2.1858449161804572e-07
# the error between 1.3862943649291992 1.3862943611198906 is 3.809308646296472e-09
# the error between 1.6094377040863037 1.6094379124341003 is 2.0834779657086244e-07
# the error between 1.7917594909667969 1.791759469228055 is 2.173874191768732e-08
# the error between 1.9459099769592285 1.9459101490553132 is 1.720960847162445e-07
# the error between 2.079441547393799 2.0794415416798357 is 5.7139630804670105e-09
# the error between 2.1972243785858154 2.1972245773362196 is 1.9875040413452894e-07
# the error between 2.3025848865509033 2.302585092994046 is 2.0644314258078111e-07
# the error between 2.397895097732544 2.3978952727983707 is 1.7506582672410786e-07
# the error between 2.4849066734313965 2.4849066497880004 is 2.3643396129813254e-08
# ...

# %%
#given functions wikth n =35
from math import sqrt
def naivelog(x):
  n=35        #step size =35
  y = x
  for i in range(n):  #this for loop calculate 35 times of the square root of y, where the initial y = x, same as sqrt(...sqrt(sqrt(x))...)
    y = sqrt(y)
  l = y-1
  for i in range(n):  #this for loop calculate 35 times of the double of given (y-1), same as 2^25*(y-1)
    l = l*2
  return l
x1=naivelog(1)
x1_=log(1)
print("the error between", x1, x1_,"is",abs(x1-x1_))
x2=naivelog(2)
x2_=log(2)
print("the error between", x2, x2_,"is",abs(x2-x2_))
x3=naivelog(3)
x3_=log(3)
print("the error between", x3, x3_,"is",abs(x3-x3_))
x4=naivelog(4)
x4_=log(4)
print("the error between", x4, x4_,"is",abs(x4-x4_))
x5=naivelog(5)
x5_=log(5)
print("the error between", x5, x5_,"is",abs(x5-x5_))
x6=naivelog(6)
x6_=log(6)
print("the error between", x6, x6_,"is",abs(x6-x6_))
x7=naivelog(7)
x7_=log(7)
print("the error between", x7, x7_,"is",abs(x7-x7_))
x8=naivelog(8)
x8_=log(8)
print("the error between", x8, x8_,"is",abs(x8-x8_))
x9=naivelog(9)
x9_=log(9)
print("the error between", x9, x9_,"is",abs(x9-x9_))
x10=naivelog(10)
x10_=log(10)
print("the error between", x10, x10_,"is",abs(x10-x10_))
x11=naivelog(11)
x11_=log(11)
print("the error between", x11, x11_,"is",abs(x11-x11_))
x12=naivelog(12)
x12_=log(12)
print("the error between", x12, x12_,"is",abs(x12-x12_))
x13=naivelog(13)
x13_=log(13)
print("the error between", x13, x13_,"is",abs(x13-x13_))
x14=naivelog(14)
x14_=log(14)
print("the error between", x14, x14_,"is",abs(x14-x14_))
def mylog(x):
  n=35
  z = x-1
  for i in range(n): #this for loop calculate the x/(1+(1+x)^(1/2)) for the given (x-1) for 35 times
    z = z/(1+sqrt(1+z))
  l = z
  for i in range(n):  #this for loop calcualte the output from the last loop and times 2 for 35 times, same as 2^35*z
    l = l*2
  return l
y1=mylog(1)
y1_=log(1)
print("the error between", y1, y1_,"is",abs(y1-y1_))
y2=mylog(2)
y2_=log(2)
print("the error between", y2, y2_,"is",abs(y2-y2_))
y3=mylog(3)
y3_=log(3)
print("the error between", y3, y3_,"is",abs(y3-y3_))
y4=mylog(4)
y4_=log(4)
print("the error between", y4, y4_,"is",abs(y4-y4_))
y5=mylog(5)
y5_=log(5)
print("the error between", y5, y5_,"is",abs(y5-y5_))
y6=mylog(6)
y6_=log(6)
print("the error between", y6, y6_,"is",abs(y6-y6_))
y7=mylog(7)
y7_=log(7)
print("the error between", y7, y7_,"is",abs(y7-y7_))
y8=mylog(8)
y8_=log(8)
print("the error between", y8, y8_,"is",abs(y8-y8_))
y9=mylog(9)
y9_=log(9)
print("the error between", y9, y9_,"is",abs(y9-y9_))
y10=mylog(10)
y10_=log(10)
print("the error between", y10, y10_,"is",abs(y10-y10_))
y11=mylog(11)
y11_=log(11)
print("the error between", y11, y11_,"is",abs(y11-y11_))
y12=mylog(12)
y12_=log(12)
print("the error between", y12, y12_,"is",abs(y12-y12_))
y13=mylog(13)
y13_=log(13)
print("the error between", y13, y13_,"is",abs(y13-y13_))
y14=mylog(14)
y14_=log(14)
print("the error between", y14, y14_,"is",abs(y14-y14_))
# Out:
# the error between 0.0 0.0 is 0.0
# the error between 0.693145751953125 0.6931471805599453 is 1.4286068202862268e-06
# the error between 1.0986099243164062 1.0986122886681098 is 2.3643517035321082e-06
# the error between 1.38629150390625 1.3862943611198906 is 2.8572136405724535e-06
# the error between 1.60943603515625 1.6094379124341003 is 1.8772778502818e-06
# the error between 1.7917556762695312 1.791759469228055 is 3.7929585237073127e-06
# the error between 1.9459075927734375 1.9459101490553132 is 2.5562818757318695e-06
# the error between 2.079437255859375 2.0794415416798357 is 4.285820460747658e-06
# the error between 2.1972198486328125 2.1972245773362196 is 4.7287034070642164e-06
# the error between 2.302581787109375 2.302585092994046 is 3.3058846709010936e-06
# the error between 2.39788818359375 2.3978952727983707 is 7.08920462066942e-06
# the error between 2.4849014282226562 2.4849066497880004 is 5.221565344104562e-06
# ...

# %%
#Q1(3)exponential function
from math import exp
def exponet(x):
  k=50     #step size 50
  y=x/(pow(2,k))   #determin y value so as to calculte (1+y)^N
  N=pow(2,k)     #determin N value through N= 2^k
  l=(1+y)
  result=pow(l,N)
  return result

x1=exponet(1)
x1_=exp(1)
print("the error between",x1, x1_,abs(x1-x1_))
x1=exponet(2)
x1_=exp(2)
print("the error between",x2, x2_,abs(x2-x2_))
x1=exponet(3)
x1_=exp(3)
print("the error between",x3, x3_,abs(x3-x3_))
x1=exponet(4)
x1_=exp(4)
print("the error between",x4, x4_,abs(x4-x4_))
x1=exponet(5)
x1_=exp(5)
print("the error between",x5, x5_,abs(x5-x5_))
x1=exponet(6)
x1_=exp(6)
print("the error between",x6, x6_,abs(x6-x6_))
x1=exponet(7)
x1_=exp(7)
print("the error between",x7, x7_,abs(x7-x7_))
x1=exponet(8)
x1_=exp(8)
print("the error between",x8, x8_,abs(x8-x8_))
x1=exponet(9)
x1_=exp(9)
print("the error between",x9, x9_,abs(x9-x9_))
x1=exponet(10)
x1_=exp(10)
print("the error between",x10, x10_,abs(x10-x10_))
x1=exponet(11)
x1_=exp(11)
print("the error between",x11, x11_,abs(x11-x11_))
x1=exponet(12)
x1_=exp(12)
print("the error between",x12, x12_,abs(x12-x12_))
x1=exponet(13)
x1_=exp(13)
print("the error between",x13, x13_,abs(x13-x13_))
# Out:
# the error between 2.718281828459044 2.718281828459045 8.881784197001252e-16
# the error between 0.693145751953125 0.6931471805599453 1.4286068202862268e-06
# the error between 1.0986099243164062 1.0986122886681098 2.3643517035321082e-06
# the error between 1.38629150390625 1.3862943611198906 2.8572136405724535e-06
# the error between 1.60943603515625 1.6094379124341003 1.8772778502818e-06
# the error between 1.7917556762695312 1.791759469228055 3.7929585237073127e-06
# the error between 1.9459075927734375 1.9459101490553132 2.5562818757318695e-06
# the error between 2.079437255859375 2.0794415416798357 4.285820460747658e-06
# the error between 2.1972198486328125 2.1972245773362196 4.7287034070642164e-06
# the error between 2.302581787109375 2.302585092994046 3.3058846709010936e-06
# the error between 2.39788818359375 2.3978952727983707 7.08920462066942e-06
# the error between 2.4849014282226562 2.4849066497880004 5.221565344104562e-06
# ...

# %%
#Q1(3) sin and cos
from math import sin,cos
def sine(x):
  k=50
  y=x/(pow(2,k))
  so=y
  for i in range(k):
    so=2*so*sqrt(1-so*so)
  result = so
  return result

def cosine(x):
  k=20
  y=x/(pow(2,k))
  co=1-(y*y)/2
  for i in range(k):
    co= 2*co*co-1
  return co
x1=sine(0.0)
x1_=sin(0.0)
print("the error between",x1, x1_,abs(x1-x1_))
x2=sine(0.1)
x2_=sin(0.1)
print("the error between",x2, x2_,abs(x2-x2_))
x3=sine(0.2)
x3_=sin(0.2)
print("the error between",x3, x3_,abs(x3-x3_))
x4=sine(0.3)
x4_=sin(0.3)
print("the error between",x4, x4_,abs(x4-x4_))
x5=sine(0.4)
x5_=sin(0.4)
print("the error between",x5, x5_,abs(x5-x5_))
x6=sine(0.5)
x6_=sin(0.5)
print("the error between",x6, x6_,abs(x6-x6_))
x7=sine(0.6)
x7_=sin(0.6)
print("the error between",x7, x7_,abs(x7-x7_))
x8=sine(0.7)
x8_=sin(0.7)
print("the error between",x8, x8_,abs(x8-x8_))
x9=sine(0.8)
x9_=sin(0.8)
print("the error between",x9, x9_,abs(x9-x9_))
x10=sine(0.9)
x10_=sin(0.9)
print("the error between",x10, x10_,abs(x10-x10_))
x11=sine(1.0)
x11_=sin(1.0)
print("the error between",x11, x11_,abs(x11-x11_))
x12=sine(1.1)
x12_=sin(1.1)
print("the error between",x12, x12_,abs(x12-x12_))
x13=sine(1.2)
x13_=sin(1.2)
print("the error between",x13, x13_,abs(x13-x13_))
x14=sine(1.3)
x14_=sin(1.3)
print("the error between",x14, x14_,abs(x14-x14_))
x15=sine(1.4)
x15_=sin(1.4)
print("the error between",x15, x15_,abs(x15-x15_))
x16=sine(1.5)
x16_=sin(1.5)
print("the error between",x16, x16_,abs(x16-x16_))
x17=sine(1.6)
x17_=sin(1.6)
print("the error between",x17, x17_,abs(x17-x17_))

#error in cosine
y1=cosine(0.0)
y1_=cos(0.0)
print("the error between",y1, y1_,abs(y1-y1_))
y2=cosine(0.1)
y2_=cos(0.1)
print("the error between",y2, y2_,abs(y2-y2_))
y3=cosine(0.2)
y3_=cos(0.2)
print("the error between",y3, y3_,abs(y3-y3_))
y4=cosine(0.3)
y4_=cos(0.3)
print("the error between",y4, y4_,abs(y4-y4_))
y5=cosine(0.4)
y5_=cos(0.4)
print("the error between",y5, y5_,abs(y5-y5_))
y6=cosine(0.5)
y6_=cos(0.5)
print("the error between",y6, y6_,abs(y6-y6_))
y7=cosine(0.6)
y7_=cos(0.6)
print("the error between",y7, y7_,abs(y7-y7_))
y8=cosine(0.7)
y8_=cos(0.7)
print("the error between",y8, y8_,abs(y8-y8_))
y9=cosine(0.8)
y9_=cos(0.8)
print("the error between",y9, y9_,abs(y9-y9_))
y10=cosine(0.9)
y10_=cos(0.9)
print("the error between",y10, y10_,abs(y10-y10_))
y11=cosine(1.0)
y11_=cos(1.0)
print("the error between",y11, y11_,abs(y11-y11_))
y12=cosine(1.1)
y12_=cos(1.1)
print("the error between",y12, y12_,abs(y12-y12_))
y13=cosine(1.2)
y13_=cos(1.2)
print("the error between",y13, y13_,abs(y13-y13_))
y14=cosine(1.3)
y14_=cos(1.3)
print("the error between",y14, y14_,abs(y14-y14_))
y15=cosine(1.4)
y15_=cos(1.4)
print("the error between",y15, y15_,abs(y15-y15_))
y16=cosine(1.5)
y16_=cos(1.5)
print("the error between",y16, y16_,abs(y16-y16_))
y17=cosine(1.6)
y17_=cos(1.6)
print("the error between",y17, y17_,abs(y17-y17_))
# Out:
# the error between 0.0 0.0 0.0
# the error between 0.09983341664682813 0.09983341664682815 2.7755575615628914e-17
# the error between 0.19866933079506116 0.19866933079506122 5.551115123125783e-17
# the error between 0.2955202066613395 0.29552020666133955 5.551115123125783e-17
# the error between 0.38941834230865036 0.3894183423086505 1.6653345369377348e-16
# the error between 0.47942553860420317 0.479425538604203 1.6653345369377348e-16
# the error between 0.5646424733950353 0.5646424733950354 1.1102230246251565e-16
# the error between 0.6442176872376909 0.644217687237691 1.1102230246251565e-16
# the error between 0.7173560908995226 0.7173560908995228 2.220446049250313e-16
# the error between 0.7833269096274833 0.7833269096274834 1.1102230246251565e-16
# the error between 0.8414709848078967 0.8414709848078965 2.220446049250313e-16
# the error between 0.8912073600614351 0.8912073600614354 3.3306690738754696e-16
# ...

# %%
from IPython.core.completer import completions_sorting_key

#Q1(4) arctangent by argument halving
import math
def arctan(x):
  k=5
  result = x
  print(result)
  for i in range(k):
    new1=(math.pow(result,2*i+1))/(2*i+1)  #new term added or minesed after tyhe result, generated by taylor series
    if i%2==0 and i !=0:        #when the index is odd, minus
      result=result-new1
    if i%2==1 and i !=0:           #when the index is even, plus
      result = result+new1
    else:
      result=result
  return result

x1=arctan(math.pi)
print(x1)
x2=arctan(pow(2,-5))
print("2^5",x2)

def tangent(l):
  k=40 #40 iterations
  z=l
  x=1/k
  y=0
  for i in range(k):
    if z >=0:            #if it rotates clockwise
      z=z - 1*arctan(pow(2,-i))    #update the rotated angle z'
      xi=x
      x=x-y*1*pow(2,-i)       #update x' through y
      y=y+xi*1*pow(2,-i)      #update y' thourgh original x
    else:               #if it rotate counter clockwise
      z=z+arctan(pow(2,-i))
      xi=x
      x=x-y*(-1)*pow(2,-i)
      y=y+xi*(-1)*pow(2,-i)
  result = x/y
  return result

x1=tangent(0.0)
print(x1)
x2=tangent(0.3)
print(x2)
x3=tangent(0.6)
print(x3)
x4=tangent(0.9)
print(x4)
x5=tangent(1.2)
print(x5)
x6=tangent(1.5)
print(x6)
x7=tangent(1.8)
print(x7)
x8=tangent(2.1)
print(x8)
x9=tangent(2.4)
print(x9)

def sine(l):
  k=40 #40 iterations
  z=l
  x=1/k
  y=0
  for i in range(k):
    if z >=0:            #if it rotates clockwise
      z=z - 1*arctan(pow(2,-i))    #update the rotated angle z'
      xi=x
      x=x-y*1*pow(2,-i)       #update x' through y
      y=y+xi*1*pow(2,-i)      #update y' thourgh original x
    else:               #if it rotate counter clockwise
      z=z+arctan(pow(2,-i))
      xi=x
      x=x-y*(-1)*pow(2,-i)
      y=y+xi*(-1)*pow(2,-i)
  return y
x1=sine(0.0)
print(x1)
x2=sine(0.3)
print(x2)
x3=sine(0.6)
print(x3)
x4=sine(0.9)
print(x4)
x5=sine(1.2)
print(x5)
x6=sine(1.5)
print(x6)
x7=sine(1.8)
print(x7)
x8=sine(2.1)
print(x8)
x9=sine(2.4)
print(x9)
def cosine(l):
  k=40 #40 iterations
  z=l
  x=1/k
  y=0
  for i in range(k):
    if z >=0:            #if it rotates clockwise
      z=z - 1*arctan(pow(2,-i))    #update the rotated angle z'
      xi=x
      x=x-y*1*pow(2,-i)       #update x' through y
      y=y+xi*1*pow(2,-i)      #update y' thourgh original x
    else:               #if it rotate counter clockwise
      z=z+arctan(pow(2,-i))
      xi=x
      x=x-y*(-1)*pow(2,-i)
      y=y+xi*(-1)*pow(2,-i)
  return x

x1=cosine(0.0)
print(x1)
x2=cosine(0.3)
print(x2)
x3=cosine(0.6)
print(x3)
x4=cosine(0.9)
print(x4)
x5=cosine(1.2)
print(x5)
x6=cosine(1.5)
print(x6)
x7=cosine(1.8)
print(x7)
x8=cosine(2.1)
print(x8)
x9=cosine(2.4)
print(x9)
# Out:
# 3.141592653589793
# 1.669819393322042e+303
# 0.03125
# 2^5 0.031260166560033595
# 1
# 0.5
# 0.25
# 0.125
# 0.0625
# 0.03125
# 0.015625
# 0.0078125
# 0.00390625
# 0.001953125
# 0.0009765625
# 0.00048828125
# 0.000244140625
# 0.0001220703125
# 6.103515625e-05
# 3.0517578125e-05
# 1.52587890625e-05
# 7.62939453125e-06
# 3.814697265625e-06
# 1.9073486328125e-06
# 9.5367431640625e-07
# 4.76837158203125e-07
# 2.384185791015625e-07
# 1.1920928955078125e-07
# 5.960464477539063e-08
# 2.9802322387695312e-08
# 1.4901161193847656e-08
# 7.450580596923828e-09
# 3.725290298461914e-09
# 1.862645149230957e-09
# 9.313225746154785e-10
# 4.656612873077393e-10
# 2.3283064365386963e-10
# 1.1641532182693481e-10
# 5.820766091346741e-11
# 2.9103830456733704e-11
# 1.4551915228366852e-11
# 7.275957614183426e-12
# 3.637978807091713e-12
# 1.8189894035458565e-12
# 2.6930021064443306
# 1
# 0.5
# 0.25
# 0.125
# 0.0625
# 0.03125
# 0.015625
# 0.0078125
# 0.00390625
# 0.001953125
# 0.0009765625
# 0.00048828125
# ...
